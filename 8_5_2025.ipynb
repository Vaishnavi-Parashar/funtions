# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi-Parashar/funtions/blob/main/8_5_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##FUNCTIONS

# %%
def Greet():
    print("hello")
Greet()
# Out:
# hello
